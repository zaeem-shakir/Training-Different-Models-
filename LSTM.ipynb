# %%
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras.datasets import fashion_mnist
from sklearn.metrics import accuracy_score, recall_score, precision_score

# Load Fashion MNIST dataset
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# Reshape and normalize images
train_images = train_images.reshape(train_images.shape[0], 28, 28) / 255.0
test_images = test_images.reshape(test_images.shape[0], 28, 28) / 255.0

# Build and compile the LSTM model
model = tf.keras.models.Sequential([
    layers.LSTM(32, input_shape=(28, 28), return_sequences=True),
    layers.LSTM(32),
    layers.Dropout(0.25),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.25),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['acc'])

# Train the model
model.fit(train_images, train_labels, batch_size=50, epochs=30)

# Predict and evaluate
predicted = model.predict(test_images)
predicted_labels = tf.argmax(predicted, axis=1)

# Calculate metrics
accuracy = accuracy_score(test_labels, predicted_labels)
precision = precision_score(test_labels, predicted_labels, average='weighted')
recall = recall_score(test_labels, predicted_labels, average='weighted')

print("Accuracy: {:.2%}".format(accuracy))
print("Precision: {:.2%}".format(precision))
print("Recall: {:.2%}".format(recall))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step
# Epoch 1/30
# 1200/1200 [==============================] - 21s 7ms/step - loss: 0.7797 - acc: 0.7075
# Epoch 2/30
# 1200/1200 [==============================] - 8s 7ms/step - loss: 0.5241 - acc: 0.8130
# Epoch 3/30
# 1200/1200 [==============================] - 8s 6ms/step - loss: 0.4582 - acc: 0.8341
# Epoch 4/30
# 1200/1200 [==============================] - 8s 7ms/step - loss: 0.4286 - acc: 0.8448
# Epoch 5/30
# 1200/1200 [==============================] - 8s 7ms/step - loss: 0.4049 - acc: 0.8530
# Epoch 6/30
# 1200/1200 [==============================] - 8s 6ms/step - loss: 0.3901 - acc: 0.8602
# Epoch 7/30
# 1200/1200 [==============================] - 8s 7ms/step - loss: 0.3749 - acc: 0.8641
# Epoch 8/30
# 1200/1200 [==============================] - 8s 7ms/step - loss: 0.3624 - acc: 0.8691
# Epoch 9/30
# 1200/1200 [==============================] - 8s 7ms/step - loss: 0.3514 - acc: 0.8735
# Epoch 10/30
# 1200/1200 [==============================] - 8s 7ms/step - loss: 0.3438 - acc: 0.8746
# Epoch 11/30
# 1200/1200 [==============================] - 8s 7ms/step - loss: 0.3328 - acc: 0.8794
# Epoch 12/30
# 1200/1200 [==============================] - 8s 7ms/step - loss: 0.3277 - acc: 0.8805
# Epoch 13/30
# 1200/1200 [==============================] - 8s 7ms/step - loss: 0.3223 - acc: 0.8839
# Epoch 14/30
# 1200/1200 [==============================] - 8s 7ms/step - loss: 0.3126 - acc: 0.8857
# Epoch 15/30
# 1200/1200 [==============================] - 8s 7ms/step - loss: 0.3093 - acc: 0.8877
# Epoch 16/30
# 1200/1200 [==============================] - 8s 7ms/step - loss: 0.3012 - acc: 0.8904
# Epoch 17/30
# 1200/1200 [==============================] - 8s 6ms/step - loss: 0.2992 - acc: 0.8924
# Epoch 18/30
# 1200/1200 [==============================] - 8s 7ms/step - loss: 0.2939 - acc: 0.8930
# Epoch 19/30
# 1200/1200 [==============================] - 8s 7ms/step - loss: 0.2893 - acc: 0.8942
# Epoch 20/30
# 1200/1200 [==============================] - 8s 7ms/step - loss: 0.2880 - acc: 0.8949
# Epoch 21/30
# 1200/1200 [==============================] - 8s 7ms/step - loss: 0.2814 - acc: 0.8975
# Epoch 22/30
# 1200/1200 [==============================] - 8s 6ms/step - loss: 0.2804 - acc: 0.8970
# Epoch 23/30
# 1200/1200 [==============================] - 8s 7ms/step - loss: 0.2750 - acc: 0.8995
# Epoch 24/30
# 1200/1200 [==============================] - 9s 8ms/step - loss: 0.2722 - acc: 0.8996
# Epoch 25/30
# 1200/1200 [==============================] - 7s 6ms/step - loss: 0.2682 - acc: 0.9024
# Epoch 26/30
# 1200/1200 [==============================] - 8s 7ms/step - loss: 0.2675 - acc: 0.9024
# Epoch 27/30
# 1200/1200 [==============================] - 8s 7ms/step - loss: 0.2613 - acc: 0.9039
# Epoch 28/30
# 1200/1200 [==============================] - 8s 6ms/step - loss: 0.2614 - acc: 0.9054
# Epoch 29/30
# 1200/1200 [==============================] - 8s 7ms/step - loss: 0.2569 - acc: 0.9062
# Epoch 30/30
# 1200/1200 [==============================] - 8s 6ms/step - loss: 0.2547 - acc: 0.9073
# 313/313 [==============================] - 2s 3ms/step
# Accuracy: 89.10%
# Precision: 89.11%
# Recall: 89.10%
